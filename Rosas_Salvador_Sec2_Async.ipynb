# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhRosas/Pepperdine/blob/main/Rosas_Salvador_Sec2_Async.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
url = 'https://raw.githubusercontent.com/ArashVafa/DESC624/master/bank-additional.csv'

bank = pd.read_table(url, sep=';')
bank.tail(10)
# Out:
#       age         job   marital            education  default  housing  \
# 4109   63     retired   married          high.school       no       no
# 4110   53   housemaid  divorced             basic.6y  unknown  unknown
# 4111   30  technician   married    university.degree       no       no
# 4112   31  technician    single  professional.course       no      yes
# 4113   31      admin.    single    university.degree       no      yes
# 4114   30      admin.   married             basic.6y       no      yes
# 4115   39      admin.   married          high.school       no      yes
# 4116   27     student    single          high.school       no       no
# 4117   58      admin.   married          high.school       no       no
# 4118   34  management    single          high.school       no      yes
#
#          loan    contact month day_of_week  ...  campaign  pdays  previous  \
# 4109       no   cellular   oct         wed  ...         1    999         0
# 4110  unknown  telephone   may         fri  ...         2    999         0
# 4111      yes   cellular   jun         fri  ...         1    999         1
# 4112       no   cellular   nov         thu  ...         1    999         0
# 4113       no   cellular   nov         thu  ...         1    999         0
# 4114      yes   cellular   jul         thu  ...         1    999         0
# 4115       no  telephone   jul         fri  ...         1    999         0
# 4116       no   cellular   may         mon  ...         2    999         1
# 4117       no   cellular   aug         fri  ...         1    999         0
# 4118       no   cellular   nov         wed  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 4109  nonexistent         -3.4          92.431          -26.9      0.740
# 4110  nonexistent          1.1          93.994          -36.4      4.855
# 4111      failure         -1.7          94.055          -39.8      0.748
# 4112  nonexistent         -0.1          93.200          -42.0      4.076
# 4113  nonexistent         -0.1          93.200          -42.0      4.076
# 4114  nonexistent          1.4          93.918          -42.7      4.958
# 4115  nonexistent          1.4          93.918          -42.7      4.959
# 4116      failure         -1.8          92.893          -46.2      1.354
# 4117  nonexistent          1.4          93.444          -36.1      4.966
# 4118  nonexistent         -0.1          93.200          -42.0      4.120
#
#       nr.employed   y
# 4109       5017.5  no
# 4110       5191.0  no
# 4111       4991.6  no
# 4112       5195.8  no
# 4113       5195.8  no
# 4114       5228.1  no
# 4115       5228.1  no
# 4116       5099.1  no
# 4117       5228.1  no
# 4118       5195.8  no
#
# [10 rows x 21 columns]

# %% [markdown]
# ## skylearn is a machine learning tool for predictive analytics
# ## we are creatinf two data sets  bank_train and bank_test
# # - The first input, bank, specifies that we are partitioning the bank data set, and the test_size = 0.25 input states that 25% of the bank data set should be in the test data set, whereas the remaining 75% should be in the training data set. The random_state input sets the seed for the random-number generator that will randomly split the data into training and test data sets -

# %%
from sklearn.model_selection import train_test_split
import random

# %%
bank_train, bank_test = train_test_split(bank, test_size = 0.25, random_state = 7) #25% test_data and 75% training_data partition

# %%
bank.shape
bank_train.shape
bank_test.shape
# Out:
# (1030, 21)

# %% [markdown]
# ## How to balance the Training Data Set in Python

# %%
bank_train['y'].value_counts()
# Out:
# no     2751
# yes     338
# Name: y, dtype: int64

# %% [markdown]
# ##The count of 'yes' responses will change depending on the partition. For the partition using the random seed specified in the previous Python code, there are 3089 records in the training data set, with 338 having the 'yes' response value. Thus, about 12% of the training data set has a 'yes' response value.

# %%
to_resample = bank_train.loc[bank_train['y'] == 'yes']
to_resample
# Out:
#       age          job   marital          education default housing loan  \
# 1409   42       admin.    single  university.degree      no     yes  yes
# 1599   44     services  divorced        high.school      no      no   no
# 2616   34       admin.    single  university.degree      no      no   no
# 3097   37       admin.   married  university.degree      no      no   no
# 3697   38     services    single        high.school      no      no   no
# ...   ...          ...       ...                ...     ...     ...  ...
# 2627   41     services   married        high.school      no     yes   no
# 1685   33  blue-collar    single        high.school      no      no   no
# 1175   36  blue-collar    single           basic.9y      no     yes  yes
# 2542   41       admin.   married           basic.6y      no      no   no
# 1486   38   technician   married  university.degree      no      no   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 1409  telephone   may         wed  ...         1    999         0
# 1599   cellular   may         mon  ...         4    999         0
# 2616   cellular   nov         thu  ...         1      7         2
# 3097  telephone   jul         mon  ...         5    999         0
# 3697   cellular   sep         fri  ...         2    999         0
# ...         ...   ...         ...  ...       ...    ...       ...
# 2627   cellular   may         wed  ...         2    999         0
# 1685   cellular   may         mon  ...         1    999         0
# 1175  telephone   jun         thu  ...         3    999         0
# 2542   cellular   apr         fri  ...         2    999         1
# 1486   cellular   jun         wed  ...         1    999         0
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 1409  nonexistent          1.1          93.994          -36.4      4.858
# 1599  nonexistent         -1.8          92.893          -46.2      1.244
# 2616      success         -3.4          92.649          -30.1      0.714
# 3097  nonexistent          1.4          93.918          -42.7      4.962
# 3697  nonexistent         -1.1          94.199          -37.5      0.878
# ...           ...          ...             ...            ...        ...
# 2627  nonexistent         -1.8          92.893          -46.2      1.281
# 1685  nonexistent         -1.8          92.893          -46.2      1.244
# 1175  nonexistent          1.4          94.465          -41.8      4.955
# 2542      failure         -1.8          93.075          -47.1      1.479
# 1486  nonexistent         -2.9          92.963          -40.8      1.260
#
#       nr.employed    y
# 1409       5191.0  yes
# 1599       5099.1  yes
# 2616       5017.5  yes
# 3097       5228.1  yes
# 3697       4963.6  yes
# ...           ...  ...
# 2627       5099.1  yes
# 1685       5099.1  yes
# 1175       5228.1  yes
# 2542       5099.1  yes
# 1486       5076.2  yes
#
# [338 rows x 21 columns]

# %% [markdown]
# # the loc command subsets the bank_train data based on the condition bank_train ['y'] == "yes" and saves the resulting data set under the name to_resample. Next, we need to sample from our records of interest

# %%
our_resample = to_resample.sample(n=170, replace = True)

# %%
our_resample
# Out:
#       age            job   marital            education default housing loan  \
# 2616   34         admin.    single    university.degree      no      no   no
# 1392   47         admin.  divorced    university.degree      no     yes   no
# 2875   29     technician   married          high.school      no     yes   no
# 3633   68        retired  divorced  professional.course      no     yes   no
# 2875   29     technician   married          high.school      no     yes   no
# ...   ...            ...       ...                  ...     ...     ...  ...
# 1272   37         admin.    single          high.school      no      no   no
# 302    57        retired   married             basic.9y      no      no   no
# 338    81        retired   married             basic.4y      no      no   no
# 3944   45         admin.  divorced          high.school      no     yes   no
# 3769   32  self-employed    single    university.degree      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 2616   cellular   nov         thu  ...         1      7         2
# 1392  telephone   jun         fri  ...         3    999         0
# 2875   cellular   jun         fri  ...         3    999         0
# 3633   cellular   oct         tue  ...         2    999         0
# 2875   cellular   jun         fri  ...         3    999         0
# ...         ...   ...         ...  ...       ...    ...       ...
# 1272   cellular   jul         thu  ...         2      7         3
# 302    cellular   aug         tue  ...         4    999         0
# 338    cellular   may         mon  ...         2    999         0
# 3944   cellular   nov         fri  ...         2    999         0
# 3769   cellular   dec         mon  ...         4    999         1
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 2616      success         -3.4          92.649          -30.1      0.714
# 1392  nonexistent          1.4          94.465          -41.8      4.967
# 2875  nonexistent         -2.9          92.963          -40.8      1.268
# 3633  nonexistent         -3.4          92.431          -26.9      0.728
# 2875  nonexistent         -2.9          92.963          -40.8      1.268
# ...           ...          ...             ...            ...        ...
# 1272      success         -1.7          94.215          -40.3      0.782
# 302   nonexistent          1.4          93.444          -36.1      4.965
# 338   nonexistent         -1.8          92.893          -46.2      1.354
# 3944  nonexistent         -0.1          93.200          -42.0      4.021
# 3769      failure         -3.0          92.713          -33.0      0.706
#
#       nr.employed    y
# 2616       5017.5  yes
# 1392       5228.1  yes
# 2875       5076.2  yes
# 3633       5017.5  yes
# 2875       5076.2  yes
# ...           ...  ...
# 1272       4991.6  yes
# 302        5228.1  yes
# 338        5099.1  yes
# 3944       5195.8  yes
# 3769       5023.5  yes
#
# [170 rows x 21 columns]

# %% [markdown]
# The sample() command draws records at random from to_resample, which holds the records we want to resample. The input n=841 specifies how many records to draw, while the input replace = True specifies the sample w/ replacement. The output is a data set made up of these 841 randomly resampled records, which we save under the name re_sample. Finally we add the resampled records to our original training data set.

# %%
bank_train_rebal = pd.concat([bank_train, our_resample])
bank_train_rebal
# Out:
#       age            job   marital          education default housing loan  \
# 751    38     management   married  university.degree      no      no  yes
# 2422   32         admin.   married  university.degree      no      no   no
# 488    40         admin.   married  university.degree      no     yes   no
# 2021   55         admin.  divorced  university.degree      no     yes   no
# 1268   51   entrepreneur   married  university.degree      no      no   no
# ...   ...            ...       ...                ...     ...     ...  ...
# 1272   37         admin.    single        high.school      no      no   no
# 302    57        retired   married           basic.9y      no      no   no
# 338    81        retired   married           basic.4y      no      no   no
# 3944   45         admin.  divorced        high.school      no     yes   no
# 3769   32  self-employed    single  university.degree      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 751    cellular   nov         fri  ...         1    999         0
# 2422  telephone   may         thu  ...         2    999         0
# 488    cellular   aug         tue  ...         1    999         0
# 2021  telephone   may         thu  ...         4    999         0
# 1268  telephone   may         wed  ...         1    999         0
# ...         ...   ...         ...  ...       ...    ...       ...
# 1272   cellular   jul         thu  ...         2      7         3
# 302    cellular   aug         tue  ...         4    999         0
# 338    cellular   may         mon  ...         2    999         0
# 3944   cellular   nov         fri  ...         2    999         0
# 3769   cellular   dec         mon  ...         4    999         1
#
#          poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 751   nonexistent         -0.1          93.200          -42.0      4.021
# 2422  nonexistent          1.1          93.994          -36.4      4.860
# 488   nonexistent          1.4          93.444          -36.1      4.966
# 2021  nonexistent          1.1          93.994          -36.4      4.855
# 1268  nonexistent          1.1          93.994          -36.4      4.856
# ...           ...          ...             ...            ...        ...
# 1272      success         -1.7          94.215          -40.3      0.782
# 302   nonexistent          1.4          93.444          -36.1      4.965
# 338   nonexistent         -1.8          92.893          -46.2      1.354
# 3944  nonexistent         -0.1          93.200          -42.0      4.021
# 3769      failure         -3.0          92.713          -33.0      0.706
#
#       nr.employed    y
# 751        5195.8   no
# 2422       5191.0   no
# 488        5228.1   no
# 2021       5191.0   no
# 1268       5191.0   no
# ...           ...  ...
# 1272       4991.6  yes
# 302        5228.1  yes
# 338        5099.1  yes
# 3944       5195.8  yes
# 3769       5023.5  yes
#
# [3259 rows x 21 columns]

# %%
bank_train_rebal['y'].value_counts() #20% = Yes
# Out:
# no     2751
# yes     508
# Name: y, dtype: int64

# %% [markdown]
# # 2.1 resample in order to have 20% of the rebalanced data set have “yes” response values

# %% [markdown]
# #*  Use your answers from the previous exercise to calculate how many “yes” response records you need to resample in order to have 20% of the rebalanced data set have “yes” response values.
# I resamples with n= 170 to have 20% Yes total rebalenced data.

# %% [markdown]
# #
# Should we balance the test data set you created above? Explain why or why not.
# - For the training model it is fine in order to minimize biased models but for a real world model I believe you should be as accurate an unbiased as possible without resampling your model to fit a narrative.
#
# Against which baseline model do we compare our classification model performance?
# - A random rate classifier would be the best baseline model to classify our datas performance.
#
# To which value does this baseline model assign all predictions? What is the accuracy of this baseline model?
# -Collinerarity seems to be the what the data is representing.
# The accuracy of the baseline for this model is = 0.20**2 + 0.80**2 = 68%

# %% [markdown]
# #Multicollinearity

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
col = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'type']

data = pd.read_csv(url, names = col)

data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         type
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %% [markdown]
# #So another thing that we do in model preparation is we look at the multicollinearity. And one good approach to doing that is to draw a pair plot. A pair plot basically plots a scatter plot of two attributes that are not the same and a histogram of the data on itself

# %%
sns.set_style('whitegrid')
sns.pairplot(data, size=3)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
correlation_matrix = data.corr().round(2)
# annot = True to print the values inside the square
sns.heatmap(data=correlation_matrix, annot=True)
# Out:
# <ipython-input-56-92c7d8511b5b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr().round(2)
# <Axes: >

# %%
#import train_test_split function
from sklearn.model_selection import train_test_split
# Split dataset into training set and test set
X_train, X_test = train_test_split(data, test_size=0.1) ### 90% training and 10% test#

# %%
colors = {'Iris-setosa': 'r', 'Iris-versicolor': 'g', 'Iris-virginica': 'b'}
# creat a figure and axis
fig, ax = plt.subplots()
#plot each data-point
for i in range(len(data['sepal_length'])):
  ax.scatter(data['sepal_length'][i], data['sepal_width'][i], color=colors[data['type'][i]])
# set a title and lables
ax.set_title("Iris DataSet")
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
# Out:
# Text(0, 0.5, 'sepal_width')

# %%
from sklearn.cluster import KMeans

iris2 = data.drop(['type'], axis = 1)
x= iris2.copy()

kmeans = KMeans(3)

kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
KMeans(algorithm='auto', copy_x= True, init= 'k-means++', max_iter= 300,
       n_clusters= 3, n_init= 10,
       random_state =None, tol= 0.0001, verbose= 0)
# Out:
# KMeans(algorithm='auto', n_clusters=3, n_init=10)

# %%
iris3 = data
iris3['predict'] = kmeans.fit_predict(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
import matplotlib.pyplot as plt
plt.scatter(iris3['sepal_length'], iris3['sepal_width'], c=iris3['predict'])
