# %% [markdown]
# <a href="https://colab.research.google.com/github/SalhRosas/Pepperdine/blob/main/Section01_DEC624.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.2 Data preparation

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ArashVafa/DESC624/master/bank_marketing_training'

bank_train = pd.read_csv(url)

bank_train.head(10)
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   56    housemaid   married     basic.4y       no      no   no  telephone
# 1   57     services   married  high.school  unknown      no   no  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   25     services    single  high.school       no     yes   no  telephone
# 4   29  blue-collar    single  high.school       no      no  yes  telephone
# 5   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 6   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 7   39   management    single     basic.9y  unknown      no   no  telephone
# 8   30   unemployed   married  high.school       no      no   no  telephone
# 9   55      retired    single  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  campaign  days_since_previous  previous  \
# 0   may         mon  ...         1                  999         0
# 1   may         mon  ...         1                  999         0
# 2   may         mon  ...         1                  999         0
# 3   may         mon  ...         1                  999         0
# 4   may         mon  ...         1                  999         0
# 5   may         mon  ...         1                  999         0
# 6   may         mon  ...         1                  999         0
# 7   may         mon  ...         1                  999         0
# 8   may         mon  ...         1                  999         0
# 9   may         mon  ...         1                  999         0
#
#    previous_outcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 0       nonexistent          1.1          93.994          -36.4      4.857
# 1       nonexistent          1.1          93.994          -36.4      4.857
# 2       nonexistent          1.1          93.994          -36.4      4.857
# 3       nonexistent          1.1          93.994          -36.4      4.857
# 4       nonexistent          1.1          93.994          -36.4      4.857
# 5       nonexistent          1.1          93.994          -36.4      4.857
# 6       nonexistent          1.1          93.994          -36.4      4.857
# 7       nonexistent          1.1          93.994          -36.4      4.857
# 8       nonexistent          1.1          93.994          -36.4      4.857
# 9       nonexistent          1.1          93.994          -36.4      4.857
#
#    nr.employed  response
# 0         5191        no
# 1         5191        no
# 2         5191        no
# 3         5191        no
# 4         5191        no
# 5         5191        no
# 6         5191        no
# 7         5191        no
# 8         5191        no
# 9         5191        no
#
# [10 rows x 21 columns]

# %%
bank_train.shape
# Out:
# (26874, 21)

# %%
bank_train['index'] = pd.Series(range(0,26874))

bank_train.head(10)
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   56    housemaid   married     basic.4y       no      no   no  telephone
# 1   57     services   married  high.school  unknown      no   no  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   25     services    single  high.school       no     yes   no  telephone
# 4   29  blue-collar    single  high.school       no      no  yes  telephone
# 5   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 6   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 7   39   management    single     basic.9y  unknown      no   no  telephone
# 8   30   unemployed   married  high.school       no      no   no  telephone
# 9   55      retired    single  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  days_since_previous  previous  previous_outcome  \
# 0   may         mon  ...                  999         0       nonexistent
# 1   may         mon  ...                  999         0       nonexistent
# 2   may         mon  ...                  999         0       nonexistent
# 3   may         mon  ...                  999         0       nonexistent
# 4   may         mon  ...                  999         0       nonexistent
# 5   may         mon  ...                  999         0       nonexistent
# 6   may         mon  ...                  999         0       nonexistent
# 7   may         mon  ...                  999         0       nonexistent
# 8   may         mon  ...                  999         0       nonexistent
# 9   may         mon  ...                  999         0       nonexistent
#
#    emp.var.rate cons.price.idx  cons.conf.idx  euribor3m  nr.employed  \
# 0           1.1         93.994          -36.4      4.857         5191
# 1           1.1         93.994          -36.4      4.857         5191
# 2           1.1         93.994          -36.4      4.857         5191
# 3           1.1         93.994          -36.4      4.857         5191
# 4           1.1         93.994          -36.4      4.857         5191
# 5           1.1         93.994          -36.4      4.857         5191
# 6           1.1         93.994          -36.4      4.857         5191
# 7           1.1         93.994          -36.4      4.857         5191
# 8           1.1         93.994          -36.4      4.857         5191
# 9           1.1         93.994          -36.4      4.857         5191
#
#    response  index
# 0        no      0
# 1        no      1
# 2        no      2
# 3        no      3
# 4        no      4
# 5        no      5
# 6        no      6
# 7        no      7
# 8        no      8
# 9        no      9
#
# [10 rows x 22 columns]

# %%
bank_train['days_since_previous'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
import numpy as np
bank_train['days_since_previous'] = bank_train['days_since_previous'].replace({999:np.NaN})

# %%
bank_train['days_since_previous'].plot(kind = 'hist', title = 'Histogram of data')
# Out:
# <Axes: title={'center': 'Histogram of data'}, ylabel='Frequency'>

# %%
import numpy as np
bank_train['days_since_previous'] = bank_train['days_since_previous'].replace({999:np.NaN})

# %%
bank_train['days_since_previous'].plot(kind = 'hist', title = 'histogram of data')
# Out:
# <Axes: title={'center': 'histogram of data'}, ylabel='Frequency'>

# %%
bank_train.head(10)
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   56    housemaid   married     basic.4y       no      no   no  telephone
# 1   57     services   married  high.school  unknown      no   no  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   25     services    single  high.school       no     yes   no  telephone
# 4   29  blue-collar    single  high.school       no      no  yes  telephone
# 5   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 6   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 7   39   management    single     basic.9y  unknown      no   no  telephone
# 8   30   unemployed   married  high.school       no      no   no  telephone
# 9   55      retired    single  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  previous  previous_outcome  emp.var.rate  \
# 0   may         mon  ...         0       nonexistent           1.1
# 1   may         mon  ...         0       nonexistent           1.1
# 2   may         mon  ...         0       nonexistent           1.1
# 3   may         mon  ...         0       nonexistent           1.1
# 4   may         mon  ...         0       nonexistent           1.1
# 5   may         mon  ...         0       nonexistent           1.1
# 6   may         mon  ...         0       nonexistent           1.1
# 7   may         mon  ...         0       nonexistent           1.1
# 8   may         mon  ...         0       nonexistent           1.1
# 9   may         mon  ...         0       nonexistent           1.1
#
#    cons.price.idx cons.conf.idx  euribor3m  nr.employed  response  index  \
# 0          93.994         -36.4      4.857         5191        no      0
# 1          93.994         -36.4      4.857         5191        no      1
# 2          93.994         -36.4      4.857         5191        no      2
# 3          93.994         -36.4      4.857         5191        no      3
# 4          93.994         -36.4      4.857         5191        no      4
# 5          93.994         -36.4      4.857         5191        no      5
# 6          93.994         -36.4      4.857         5191        no      6
# 7          93.994         -36.4      4.857         5191        no      7
# 8          93.994         -36.4      4.857         5191        no      8
# 9          93.994         -36.4      4.857         5191        no      9
#
#    education_numeric
# 0           basic.4y
# 1        high.school
# 2            unknown
# 3        high.school
# 4        high.school
# 5           basic.4y
# 6           basic.6y
# 7           basic.9y
# 8        high.school
# 9        high.school
#
# [10 rows x 23 columns]

# %%
bank_train["education_numeric"]= bank_train["education"]

# %%
dict_edu = {"education_numeric": {"illustrate": 0, "basic.4y": 4, "basic.6y": 6, "basic.9y": 9, "high.school":12, "professional.course":12, "university.degree":16, 'unknown' : np.NaN}}

# %%
bank_train.replace(dict_edu, inplace = True)

# %%
bank_train.head(10)
# Out:
#    age          job   marital    education  default housing loan    contact  \
# 0   56    housemaid   married     basic.4y       no      no   no  telephone
# 1   57     services   married  high.school  unknown      no   no  telephone
# 2   41  blue-collar   married      unknown  unknown      no   no  telephone
# 3   25     services    single  high.school       no     yes   no  telephone
# 4   29  blue-collar    single  high.school       no      no  yes  telephone
# 5   57    housemaid  divorced     basic.4y       no     yes   no  telephone
# 6   35  blue-collar   married     basic.6y       no     yes   no  telephone
# 7   39   management    single     basic.9y  unknown      no   no  telephone
# 8   30   unemployed   married  high.school       no      no   no  telephone
# 9   55      retired    single  high.school       no     yes   no  telephone
#
#   month day_of_week  ...  previous  previous_outcome  emp.var.rate  \
# 0   may         mon  ...         0       nonexistent           1.1
# 1   may         mon  ...         0       nonexistent           1.1
# 2   may         mon  ...         0       nonexistent           1.1
# 3   may         mon  ...         0       nonexistent           1.1
# 4   may         mon  ...         0       nonexistent           1.1
# 5   may         mon  ...         0       nonexistent           1.1
# 6   may         mon  ...         0       nonexistent           1.1
# 7   may         mon  ...         0       nonexistent           1.1
# 8   may         mon  ...         0       nonexistent           1.1
# 9   may         mon  ...         0       nonexistent           1.1
#
#    cons.price.idx cons.conf.idx  euribor3m  nr.employed  response  index  \
# 0          93.994         -36.4      4.857         5191        no      0
# 1          93.994         -36.4      4.857         5191        no      1
# 2          93.994         -36.4      4.857         5191        no      2
# 3          93.994         -36.4      4.857         5191        no      3
# 4          93.994         -36.4      4.857         5191        no      4
# 5          93.994         -36.4      4.857         5191        no      5
# 6          93.994         -36.4      4.857         5191        no      6
# 7          93.994         -36.4      4.857         5191        no      7
# 8          93.994         -36.4      4.857         5191        no      8
# 9          93.994         -36.4      4.857         5191        no      9
#
#    education_numeric
# 0                  4
# 1                 12
# 2                NaN
# 3                 12
# 4                 12
# 5                  4
# 6                  6
# 7                  9
# 8                 12
# 9                 12
#
# [10 rows x 23 columns]

# %%
from scipy import stats
bank_train['age_z'] = stats.zscore(bank_train['age'])

bank_train['age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
bank_train['age_z'].plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
bank_train_outliers = bank_train.query('age_z >3' or 'age_z < -3')

# %%
bank_train_sort = bank_train.sort_values(['age_z'], ascending = False)

# %%
bank_train_sort[['age', 'marital']].head(n=15)
# Out:
#        age   marital
# 24840   91   married
# 24833   91   married
# 26520   89  divorced
# 26015   89  divorced
# 18179   88  divorced
# 18181   88  divorced
# 18183   88  divorced
# 18186   88  divorced
# 18187   88  divorced
# 18188   88  divorced
# 25098   88  divorced
# 18190   88  divorced
# 18191   88  divorced
# 26516   88   married
# 26509   88   married

# %% [markdown]
# Bar Graphs with response overlay

# %%
crosstab_01 = pd.crosstab(bank_train['previous_outcome'], bank_train['response'])

# %%
crosstab_norm = crosstab_01.div(crosstab_01.sum(1), axis = 0)

# %%
crosstab_01.plot(kind='bar', stacked = True)
# Out:
# <Axes: xlabel='previous_outcome'>

# %%
crosstab_norm.plot(kind='bar', stacked = True)
# Out:
# <Axes: xlabel='previous_outcome'>

# %%
crosstab_01 = pd.crosstab(bank_train['previous_outcome'], bank_train ['response'])

crosstab_02 =pd.crosstab(bank_train['response'], bank_train['previous_outcome'],)

# %%
round(crosstab_02.div(crosstab_02.sum(0),axis = 1)*100, 1)
# Out:
# previous_outcome  failure  nonexistent  success
# response
# no                   86.1         91.2     36.0
# yes                  13.9          8.8     64.0
